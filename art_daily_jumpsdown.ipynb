# %%
import pandas as pd

df=pd.read_csv('art_daily_jumpsdown.csv')
df.plot()
# Out:
# <Axes: >

# %%
threshold = 40
min_count=3

over= (50>df['value']) & (df['value']>threshold)
df['anomaly']=over.rolling(min_count).sum() == min_count
df[df['anomaly']]
# Out:
#                 timestamp      value  anomaly
# 3065  2014-04-11 15:25:00  41.737377     True
# 3078  2014-04-11 16:30:00  42.074102     True
# 3084  2014-04-11 17:00:00  43.719990     True

# %%
gap=df['value'].diff().abs().rolling(min_count).sum()>4
gap
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4027    False
# 4028     True
# 4029    False
# 4030    False
# 4031    False
# Name: value, Length: 4032, dtype: bool
