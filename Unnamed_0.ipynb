# %% [markdown]
# <a href="https://colab.research.google.com/github/zo-ff/pandas/blob/main/Unnamed_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Unnamed:0***

# %%
# 保存時、インデックスを列として書き出さない
df.pd_csv("data.csv", index=False)

# %%
# 読み込み時
# 数値インデックスの場合
df = pd.read_csv("data.csv", index_col=0)

# 意味のある列をインデックスにする場合
df = pd.read_csv("data.csv", index_col="equipment_id")

# %%
# 保存時にindex=Falseつけておけば読み込み時に何もしなくていい
df.pd_csv("data.csv", index=False)
df = pd.read_csv("data.csv")   # そのままでOK
